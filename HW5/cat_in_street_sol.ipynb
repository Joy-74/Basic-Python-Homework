# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
street=mpimg.imread('street.png') 
cat = mpimg.imread('cat.png') 
plt.imshow(street)

# %%
# write your code in this cell.
r, g, b = cat[:,:,0], cat[...,1], cat[...,2]  # each of r, g, and b has shape (224, 224)

mask = np.logical_not((r > 0.98) & (g > 0.98) & (b > 0.98))      # mask has shape (224, 224)
print(mask.shape)


street_patch = street[-224:,:224, :]
street_patch[mask] = cat[mask]
# Out:
# (224, 224)

# %%
plt.imshow(street)
# you should see an image similar to the one provided in HW5.pdf
